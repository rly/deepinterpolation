# %%
import deepinterpolation as de
import sys
from shutil import copyfile
import os
from deepinterpolation.generic import JsonSaver, ClassLoader
import datetime
from typing import Any, Dict
import pathlib
import sys

# %% [markdown]
# This is used for record-keeping

# %%
now = datetime.datetime.now()
run_uid = now.strftime("%Y_%m_%d_%H_%M")

# %% [markdown]
# Initialize meta-parameters objects

# %%
training_param = {}
generator_param = {}
network_param = {}
generator_test_param = {}

# %% [markdown]
# An epoch is defined as the number of batches pulled from the dataset. Because our datasets are VERY large. Often, we cannot
# go through the entirity of the data so we define an epoch slightly differently than is usual.

# %%
steps_per_epoch = 10

# %% [markdown]
# Those are parameters used for the Validation test generator. Here the test is done on the beginning of the data but
# this can be a separate file

# %%
generator_test_param["type"] = "generator"  # type of collection
generator_test_param["name"] = "MDAEphysGenerator"  # Name of object in the collection
generator_test_param[
    "pre_post_frame"
] = 30  # Number of frame provided before and after the predicted frame
generator_test_param["train_path"] = os.path.join(
    "..",
    "data",
    "PAIRED_KAMPFF",
    "c14",
)
generator_test_param["batch_size"] = 100
generator_test_param["start_frame"] = 100
generator_test_param["end_frame"] = 1999
generator_test_param[
    "pre_post_omission"
] = 1  # Number of frame omitted before and after the predicted frame
generator_test_param["steps_per_epoch"] = -1  # No step necessary for testing as epochs are not relevant. -1 deactivate it.

# %% [markdown]
# Those are parameters used for the main data generator

# %%
generator_param["type"] = "generator"
generator_param["steps_per_epoch"] = steps_per_epoch
generator_param["name"] = "MDAEphysGenerator"
generator_param["pre_post_frame"] = 30
generator_param["train_path"] = os.path.join(
    "..",
    "data",
    "PAIRED_KAMPFF",
    "c14",
)
generator_param["batch_size"] = 100
generator_param["start_frame"] = 2000
generator_param["end_frame"] = -1
generator_param["pre_post_omission"] = 1

# %% [markdown]
# Those are parameters used for the network topology

# %%
network_param["type"] = "network"
network_param[
    "name"
] = "unet_single_ephys_256"  # Name of network topology in the collection

# %% [markdown]
# Those are parameters used for the training process

# %%
training_param["type"] = "trainer"
training_param["name"] = "core_trainer"
training_param["run_uid"] = run_uid
training_param["batch_size"] = generator_test_param["batch_size"]
training_param["steps_per_epoch"] = steps_per_epoch
training_param[
    "period_save"
] = 25  # network model is potentially saved during training between a regular nb epochs
training_param["nb_gpus"] = 0
training_param["apply_learning_decay"] = 0
training_param[
    "nb_times_through_data"
] = 1  # if you want to cycle through the entire data. Two many iterations will cause noise overfitting
training_param["learning_rate"] = 0.0001
training_param["pre_post_frame"] = generator_test_param["pre_post_frame"]
training_param["loss"] = "mean_absolute_error"
training_param[
    "nb_workers"
] = 1  # this is to enable multiple threads for data generator loading. Useful when this is slower than training

training_param["model_string"] = (
    network_param["name"]
    + "_"
    + training_param["loss"]
    + "_"
    + training_param["run_uid"]
)

# %% [markdown]
# Where do you store ongoing training progress

# %%
jobdir = os.path.join(
    "ephys", training_param["model_string"] + "_" + run_uid,
)
training_param["output_dir"] = jobdir

try:
    os.makedirs(jobdir)
except FileExistsError:
    print("folder already exists")

# %% [markdown]
# Here we create all json files that are fed to the training. This is used for recording purposes as well as input to the training proces

# %%
path_training = os.path.join(jobdir, "training.json")
json_obj = JsonSaver(training_param)
json_obj.save_json(path_training)

path_generator = os.path.join(jobdir, "generator.json")
json_obj = JsonSaver(generator_param)
json_obj.save_json(path_generator)

path_test_generator = os.path.join(jobdir, "test_generator.json")
json_obj = JsonSaver(generator_test_param)
json_obj.save_json(path_test_generator)

path_network = os.path.join(jobdir, "network.json")
json_obj = JsonSaver(network_param)
json_obj.save_json(path_network)

# %% [markdown]
# Here we create all objects for training.

# %%
# We find the generator obj in the collection using the json file
generator_obj = ClassLoader(path_generator)
generator_test_obj = ClassLoader(path_test_generator)

# We find the network obj in the collection using the json file
network_obj = ClassLoader(path_network)

# We find the training obj in the collection using the json file
trainer_obj = ClassLoader(path_training)

# We build the generators object. This will, among other things, calculate normalizing parameters.
train_generator = generator_obj.find_and_build()(path_generator)
test_generator = generator_test_obj.find_and_build()(path_test_generator)

# We build the network object. This will, among other things, calculate normalizing parameters.
network_callback = network_obj.find_and_build()(path_network)

# We build the training object.
training_class = trainer_obj.find_and_build()(train_generator, test_generator, network_callback, path_training)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# Start training. This can take very long time.

# %%
training_class.run()
# Out:
# Epoch 1/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 101s 10s/step - loss: 0.4039 - val_loss: 0.3782
# Epoch 2/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 146s 15s/step - loss: 0.3716 - val_loss: 0.3597
# Epoch 3/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 135s 14s/step - loss: 0.3506 - val_loss: 0.3607
# Epoch 4/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 155s 15s/step - loss: 0.3594 - val_loss: 0.3440
# Epoch 5/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 19460s 1946s/step - loss: 0.3408 - val_loss: 0.3402
# Epoch 6/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.3303 - val_loss: 0.3342
# Epoch 7/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 76s 8s/step - loss: 0.3309 - val_loss: 0.3325
# Epoch 8/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.3225 - val_loss: 0.3268
# Epoch 9/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.3234 - val_loss: 0.3317
# Epoch 10/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.3464 - val_loss: 0.3210
# Epoch 11/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.4248 - val_loss: 0.3187
# Epoch 12/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.4823 - val_loss: 0.3155
# Epoch 13/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.4435 - val_loss: 0.3106
# Epoch 14/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 6s/step - loss: 0.3513 - val_loss: 0.3090
# Epoch 15/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.4076 - val_loss: 0.3095
# Epoch 16/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 6s/step - loss: 0.3718 - val_loss: 0.3060
# Epoch 17/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.3559 - val_loss: 0.3060
# Epoch 18/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.3490 - val_loss: 0.3062
# Epoch 19/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.3727 - val_loss: 0.3083
# Epoch 20/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.3503 - val_loss: 0.3019
# Epoch 21/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.3652 - val_loss: 0.3041
# Epoch 22/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.3186 - val_loss: 0.3026
# Epoch 23/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 62s 6s/step - loss: 0.3135 - val_loss: 0.2985
# Epoch 24/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.3012 - val_loss: 0.3031
# Epoch 25/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.3015
# Epoch 00025: val_loss improved from inf to 0.29633, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0025-0.2963.h5
# 10/10 [==============================] - 61s 6s/step - loss: 0.3015 - val_loss: 0.2963
# Epoch 26/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2965 - val_loss: 0.2957
# Epoch 27/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2987 - val_loss: 0.2960
# Epoch 28/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.2934 - val_loss: 0.2931
# Epoch 29/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.2937 - val_loss: 0.2927
# Epoch 30/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2935 - val_loss: 0.2913
# Epoch 31/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 69s 7s/step - loss: 0.2914 - val_loss: 0.2923
# Epoch 32/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.2888 - val_loss: 0.2900
# Epoch 33/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.2955 - val_loss: 0.2897
# Epoch 34/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 65s 6s/step - loss: 0.2910 - val_loss: 0.2902
# Epoch 35/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2894 - val_loss: 0.2885
# Epoch 36/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2899 - val_loss: 0.2881
# Epoch 37/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 75s 7s/step - loss: 0.2873 - val_loss: 0.2903
# Epoch 38/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 67s 7s/step - loss: 0.2902 - val_loss: 0.2869
# Epoch 39/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 71s 7s/step - loss: 0.2860 - val_loss: 0.2884
# Epoch 40/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 72s 7s/step - loss: 0.2842 - val_loss: 0.2853
# Epoch 41/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 69s 7s/step - loss: 0.2892 - val_loss: 0.2885
# Epoch 42/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2856 - val_loss: 0.2848
# Epoch 43/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 69s 7s/step - loss: 0.2864 - val_loss: 0.2855
# Epoch 44/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 70s 7s/step - loss: 0.2880 - val_loss: 0.2841
# Epoch 45/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 67s 7s/step - loss: 0.2850 - val_loss: 0.2833
# Epoch 46/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2867 - val_loss: 0.2833
# Epoch 47/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2875 - val_loss: 0.2902
# Epoch 48/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.3061 - val_loss: 0.2859
# Epoch 49/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 73s 7s/step - loss: 0.3969 - val_loss: 0.2833
# Epoch 50/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.3959
# Epoch 00050: val_loss improved from 0.29633 to 0.28284, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0050-0.2828.h5
# 10/10 [==============================] - 73s 7s/step - loss: 0.3959 - val_loss: 0.2828
# Epoch 51/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 73s 7s/step - loss: 0.3279 - val_loss: 0.2827
# Epoch 52/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.3422 - val_loss: 0.2869
# Epoch 53/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 63s 6s/step - loss: 0.3372 - val_loss: 0.2828
# Epoch 54/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.3153 - val_loss: 0.2854
# Epoch 55/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 65s 6s/step - loss: 0.3211 - val_loss: 0.2828
# Epoch 56/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.3066 - val_loss: 0.2814
# Epoch 57/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 67s 7s/step - loss: 0.3040 - val_loss: 0.2824
# Epoch 58/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 73s 7s/step - loss: 0.2967 - val_loss: 0.2818
# Epoch 59/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 70s 7s/step - loss: 0.2841 - val_loss: 0.2805
# Epoch 60/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 72s 7s/step - loss: 0.2845 - val_loss: 0.2799
# Epoch 61/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2892 - val_loss: 0.2793
# Epoch 62/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 68s 7s/step - loss: 0.2835 - val_loss: 0.2797
# Epoch 63/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2807 - val_loss: 0.2791
# Epoch 64/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2795 - val_loss: 0.2785
# Epoch 65/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 63s 6s/step - loss: 0.2788 - val_loss: 0.2796
# Epoch 66/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2756 - val_loss: 0.2775
# Epoch 67/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2778 - val_loss: 0.2774
# Epoch 68/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2776 - val_loss: 0.2801
# Epoch 69/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2793 - val_loss: 0.2799
# Epoch 70/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 6s/step - loss: 0.2830 - val_loss: 0.2778
# Epoch 71/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2819 - val_loss: 0.2773
# Epoch 72/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2844 - val_loss: 0.2767
# Epoch 73/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2881 - val_loss: 0.2794
# Epoch 74/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2954 - val_loss: 0.2765
# Epoch 75/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.2901
# Epoch 00075: val_loss improved from 0.28284 to 0.27657, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0075-0.2766.h5
# 10/10 [==============================] - 52s 5s/step - loss: 0.2901 - val_loss: 0.2766
# Epoch 76/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2826 - val_loss: 0.2783
# Epoch 77/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2806 - val_loss: 0.2758
# Epoch 78/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2762 - val_loss: 0.2767
# Epoch 79/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2713 - val_loss: 0.2756
# Epoch 80/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2713 - val_loss: 0.2764
# Epoch 81/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2747 - val_loss: 0.2761
# Epoch 82/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2734 - val_loss: 0.2745
# Epoch 83/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.2753 - val_loss: 0.2753
# Epoch 84/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2768 - val_loss: 0.2743
# Epoch 85/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 61s 6s/step - loss: 0.2733 - val_loss: 0.2770
# Epoch 86/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2761 - val_loss: 0.2745
# Epoch 87/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.2742 - val_loss: 0.2753
# Epoch 88/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2713 - val_loss: 0.2736
# Epoch 89/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2741 - val_loss: 0.2747
# Epoch 90/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2754 - val_loss: 0.2753
# Epoch 91/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2854 - val_loss: 0.2753
# Epoch 92/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.3109 - val_loss: 0.2769
# Epoch 93/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.3513 - val_loss: 0.2752
# Epoch 94/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.3083 - val_loss: 0.2752
# Epoch 95/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2908 - val_loss: 0.2737
# Epoch 96/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.3001 - val_loss: 0.2739
# Epoch 97/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.3161 - val_loss: 0.2763
# Epoch 98/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.3122 - val_loss: 0.2746
# Epoch 99/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.3098 - val_loss: 0.2747
# Epoch 100/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.2967
# Epoch 00100: val_loss improved from 0.27657 to 0.27378, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0100-0.2738.h5
# 10/10 [==============================] - 60s 6s/step - loss: 0.2967 - val_loss: 0.2738
# Epoch 101/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 61s 6s/step - loss: 0.3064 - val_loss: 0.2746
# Epoch 102/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.2997 - val_loss: 0.2737
# Epoch 103/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2840 - val_loss: 0.2732
# Epoch 104/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 6s/step - loss: 0.2754 - val_loss: 0.2727
# Epoch 105/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.2723 - val_loss: 0.2732
# Epoch 106/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2698 - val_loss: 0.2716
# Epoch 107/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2711 - val_loss: 0.2713
# Epoch 108/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 63s 6s/step - loss: 0.2718 - val_loss: 0.2747
# Epoch 109/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2716 - val_loss: 0.2716
# Epoch 110/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 60s 6s/step - loss: 0.2704 - val_loss: 0.2712
# Epoch 111/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 62s 6s/step - loss: 0.2779 - val_loss: 0.2712
# Epoch 112/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2757 - val_loss: 0.2713
# Epoch 113/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2735 - val_loss: 0.2704
# Epoch 114/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 61s 6s/step - loss: 0.2693 - val_loss: 0.2701
# Epoch 115/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2688 - val_loss: 0.2697
# Epoch 116/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2701 - val_loss: 0.2700
# Epoch 117/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2689 - val_loss: 0.2698
# Epoch 118/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.2702 - val_loss: 0.2726
# Epoch 119/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2675 - val_loss: 0.2700
# Epoch 120/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 5s/step - loss: 0.2770 - val_loss: 0.2717
# Epoch 121/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2772 - val_loss: 0.2690
# Epoch 122/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2980 - val_loss: 0.2705
# Epoch 123/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2912 - val_loss: 0.2693
# Epoch 124/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2803 - val_loss: 0.2685
# Epoch 125/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.2771
# Epoch 00125: val_loss improved from 0.27378 to 0.26841, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0125-0.2684.h5
# 10/10 [==============================] - 54s 5s/step - loss: 0.2771 - val_loss: 0.2684
# Epoch 126/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2725 - val_loss: 0.2673
# Epoch 127/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 55s 6s/step - loss: 0.2680 - val_loss: 0.2671
# Epoch 128/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2649 - val_loss: 0.2684
# Epoch 129/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2664 - val_loss: 0.2688
# Epoch 130/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2656 - val_loss: 0.2672
# Epoch 131/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2631 - val_loss: 0.2683
# Epoch 132/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2665 - val_loss: 0.2664
# Epoch 133/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2616 - val_loss: 0.2667
# Epoch 134/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2634 - val_loss: 0.2662
# Epoch 135/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2634 - val_loss: 0.2658
# Epoch 136/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2628 - val_loss: 0.2658
# Epoch 137/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2633 - val_loss: 0.2666
# Epoch 138/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2646 - val_loss: 0.2674
# Epoch 139/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2630 - val_loss: 0.2661
# Epoch 140/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2622 - val_loss: 0.2659
# Epoch 141/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2625 - val_loss: 0.2670
# Epoch 142/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2608 - val_loss: 0.2705
# Epoch 143/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2598 - val_loss: 0.2656
# Epoch 144/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2662 - val_loss: 0.2659
# Epoch 145/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2763 - val_loss: 0.2658
# Epoch 146/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.3186 - val_loss: 0.2693
# Epoch 147/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.3088 - val_loss: 0.2651
# Epoch 148/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2913 - val_loss: 0.2654
# Epoch 149/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2818 - val_loss: 0.2645
# Epoch 150/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.2710
# Epoch 00150: val_loss improved from 0.26841 to 0.26478, saving model to ephys\unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02_2021_09_16_03_02\2021_09_16_03_02_unet_single_ephys_256_mean_absolute_error_2021_09_16_03_02-0150-0.2648.h5
# 10/10 [==============================] - 52s 5s/step - loss: 0.2710 - val_loss: 0.2648
# Epoch 151/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2667 - val_loss: 0.2645
# Epoch 152/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2676 - val_loss: 0.2645
# Epoch 153/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2788 - val_loss: 0.2646
# Epoch 154/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 54s 5s/step - loss: 0.2841 - val_loss: 0.2648
# Epoch 155/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2779 - val_loss: 0.2645
# Epoch 156/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2760 - val_loss: 0.2649
# Epoch 157/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2806 - val_loss: 0.2645
# Epoch 158/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2695 - val_loss: 0.2651
# Epoch 159/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2683 - val_loss: 0.2643
# Epoch 160/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2609 - val_loss: 0.2638
# Epoch 161/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2630 - val_loss: 0.2640
# Epoch 162/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2610 - val_loss: 0.2640
# Epoch 163/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2596 - val_loss: 0.2654
# Epoch 164/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2610 - val_loss: 0.2693
# Epoch 165/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2619 - val_loss: 0.2753
# Epoch 166/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 53s 5s/step - loss: 0.2625 - val_loss: 0.2656
# Epoch 167/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2604 - val_loss: 0.2657
# Epoch 168/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 52s 5s/step - loss: 0.2612 - val_loss: 0.2700
# Epoch 169/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2624 - val_loss: 0.2668
# Epoch 170/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2613 - val_loss: 0.2677
# Epoch 171/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 51s 5s/step - loss: 0.2627 - val_loss: 0.2666
# Epoch 172/32399
# ...
# 10/10 [==============================] - 75s 7s/step - loss: 0.2756 - val_loss: 0.2667
# Epoch 634/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 71s 7s/step - loss: 0.2675 - val_loss: 0.2676
# Epoch 635/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 70s 7s/step - loss: 0.2712 - val_loss: 0.2673
# Epoch 636/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 74s 7s/step - loss: 0.2702 - val_loss: 0.2670
# Epoch 637/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 75s 8s/step - loss: 0.2637 - val_loss: 0.2669
# Epoch 638/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 74s 7s/step - loss: 0.2578 - val_loss: 0.2666
# Epoch 639/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 80s 8s/step - loss: 0.2602 - val_loss: 0.2666
# Epoch 640/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 76s 8s/step - loss: 0.2539 - val_loss: 0.2675
# Epoch 641/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 76s 8s/step - loss: 0.2577 - val_loss: 0.2666
# Epoch 642/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 74s 7s/step - loss: 0.2545 - val_loss: 0.2663
# Epoch 643/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 72s 7s/step - loss: 0.2538 - val_loss: 0.2674
# Epoch 644/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.2568 - val_loss: 0.2669
# Epoch 645/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2555 - val_loss: 0.2673
# Epoch 646/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2576 - val_loss: 0.2676
# Epoch 647/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2553 - val_loss: 0.2670
# Epoch 648/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2570 - val_loss: 0.2677
# Epoch 649/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 66s 7s/step - loss: 0.2553 - val_loss: 0.2668
# Epoch 650/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - ETA: 0s - loss: 0.2579
# Epoch 00650: val_loss did not improve from 0.26440
# 10/10 [==============================] - 62s 6s/step - loss: 0.2579 - val_loss: 0.2672
# Epoch 651/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 60s 6s/step - loss: 0.2574 - val_loss: 0.2667
# Epoch 652/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 60s 6s/step - loss: 0.2619 - val_loss: 0.2671
# Epoch 653/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.2645 - val_loss: 0.2667
# Epoch 654/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2818 - val_loss: 0.2677
# Epoch 655/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.2877 - val_loss: 0.2679
# Epoch 656/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 65s 6s/step - loss: 0.2740 - val_loss: 0.2681
# Epoch 657/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 64s 6s/step - loss: 0.2679 - val_loss: 0.2679
# Epoch 658/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.2786 - val_loss: 0.2671
# Epoch 659/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.2735 - val_loss: 0.2698
# Epoch 660/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2702 - val_loss: 0.2671
# Epoch 661/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 59s 6s/step - loss: 0.2643 - val_loss: 0.2672
# Epoch 662/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 56s 6s/step - loss: 0.2616 - val_loss: 0.2670
# Epoch 663/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2611 - val_loss: 0.2668
# Epoch 664/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2574 - val_loss: 0.2670
# Epoch 665/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2558 - val_loss: 0.2681
# Epoch 666/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2563 - val_loss: 0.2689
# Epoch 667/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2536 - val_loss: 0.2685
# Epoch 668/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 57s 6s/step - loss: 0.2557 - val_loss: 0.2696
# Epoch 669/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 60s 6s/step - loss: 0.2557 - val_loss: 0.2703
# Epoch 670/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 60s 6s/step - loss: 0.2563 - val_loss: 0.2696
# Epoch 671/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2555 - val_loss: 0.2702
# Epoch 672/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2529 - val_loss: 0.2692
# Epoch 673/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2546 - val_loss: 0.2698
# Epoch 674/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/10 [==============================] - 58s 6s/step - loss: 0.2542 - val_loss: 0.2724
# Epoch 675/32399
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#  7/10 [====================>.........] - ETA: 15s - loss: 0.2568
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-de1759d1cffb> in <module>
# ----> 1 training_class.run()
#
# c:\users\ryan\documents\spikesorting\deepinterpolation\deepinterpolation\trainor_collection.py in run(self)
#     232
#     233         if self.steps_per_epoch > 0:
# --> 234             self.model_train = self.local_model.fit(
#     235                 self.local_generator,
#     236                 validation_data=self.local_test_generator,
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\miniconda3\envs\di2\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Finalize and save output of the training.

# %%
training_class.finalize()
